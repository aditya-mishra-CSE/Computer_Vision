# %%
import cv2

# %%
#Read the image using OpenCV
image = cv2.imread('/content/heart.jfif')

# %%
image.shape
# Out:
# (2737, 2000, 3)

# %%
image
# Out:
# array([[[252, 254, 254],
#         [252, 254, 254],
#         [252, 254, 254],
#         ...,
#         [252, 254, 254],
#         [252, 254, 254],
#         [252, 254, 254]],
#
#        [[252, 254, 254],
#         [252, 254, 254],
#         [252, 254, 254],
#         ...,
#         [252, 254, 254],
#         [252, 254, 254],
#         [252, 254, 254]],
#
#        [[252, 254, 254],
#         [252, 254, 254],
#         [252, 254, 254],
#         ...,
#         [252, 254, 254],
#         [252, 254, 254],
#         [252, 254, 254]],
#
#        ...,
#
#        [[215, 224, 234],
#         [216, 225, 235],
#         [217, 226, 236],
#         ...,
#         [211, 211, 229],
#         [211, 211, 229],
#         [211, 211, 229]],
#
#        [[215, 224, 234],
#         [216, 225, 235],
#         [216, 225, 235],
#         ...,
#         [211, 211, 229],
#         [211, 211, 229],
#         [211, 211, 229]],
#
#        [[216, 225, 235],
#         [217, 226, 236],
#         [217, 226, 236],
#         ...,
#         [211, 210, 230],
#         [210, 209, 229],
#         [210, 209, 229]]], dtype=uint8)

# %%
#Print the pixels value
print(image)

# %%
#Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
gray_image
# Out:
# array([[254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        ...,
#        [226, 227, 228, ..., 216, 216, 216],
#        [226, 227, 227, ..., 216, 216, 216],
#        [227, 228, 228, ..., 216, 215, 215]], dtype=uint8)

# %%
from google.colab.patches import cv2_imshow

#Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

#Save and display the grayscale image
cv2.imwrite('gray_image.jpg', gray_image)
cv2_imshow(gray_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
